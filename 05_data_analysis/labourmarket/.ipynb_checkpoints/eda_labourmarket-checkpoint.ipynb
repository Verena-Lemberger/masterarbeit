# %%
# load libraries
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt 
import matplotlib as mpl
sns.set(color_codes=True)
from datetime import date
from datetime import datetime
from sklearn.linear_model import LinearRegression
import warnings
warnings.filterwarnings("ignore")

# %%
# load data
#df = pd.read_excel("AL_Tirol_seit 1987.xlsx")
#df.head()

xls = pd.ExcelFile("AL_Tirol_seit 1987.xlsx")
df_age = pd.read_excel(xls, "nach Alter")
df_edu = pd.read_excel(xls, "nach Ausbildung")
df_disa = pd.read_excel(xls, "nach Behinderung")

print(df_age.head(10))
df_age.info()

print(df_edu.head(10))
df_edu.info()

print(df_disa.head(10))
df_disa.info()
# Out:
#                                      AL - arbeitslos   Unnamed: 1  \
# 0                                              Tirol          NaN
# 1  Elemente unterdrücken - Summe ist ein Null- od...          NaN
# 2                                            Bestand  1987.000000
# 3                                       bis 19 Jahre  1098.833333
# 4                                    20 bis 24 Jahre  2855.083333
# 5                                    25 bis 29 Jahre  2160.083333
# 6                                    30 bis 34 Jahre  1490.833333
# 7                                    35 bis 39 Jahre  1274.250000
# 8                                    40 bis 44 Jahre  1077.500000
# 9                                    45 bis 49 Jahre  1055.750000
#
#     Unnamed: 2   Unnamed: 3   Unnamed: 4   Unnamed: 5   Unnamed: 6  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# ...
